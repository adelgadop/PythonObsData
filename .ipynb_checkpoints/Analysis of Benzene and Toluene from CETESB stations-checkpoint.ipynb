# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
# %matplotlib inline

# %% [markdown]
# # Import data downloaded from QUALAR
# We import sations that content Toluene and Benzene as measurementes.
# After that, we import air quality data saving in pickle format.

# %%
stations = pd.read_csv('stations_hc.csv')
#stations = stations.loc[stations.domain =='d02']\
#            .drop('domain', axis=1).sort_values(by='code')
stations.index =stations.code
stations
# Out:
#                            name        lat        lon  code            type  \
# code
# 91              Cerqueira César -23.553543 -46.672705    91           Urban
# 117                    Paulínia -22.772321 -47.154843   117        Industry
# 99                    Pinheiros -23.561460 -46.702017    99           Urban
# 100             S.André-Capuava -23.639804 -46.491637   100           Urban
# 88                S.José Campos -23.187887 -45.871198    88  Regional urban
# 278   S.José Campos-Vista Verde -23.183697 -45.830897   278  Regional urban
#
#      domain   abb
# code
# 91      d02   CeC
# 117     d02   Pln
# 99      d02  Pinh
# 100     d02  SACp
# 88      d02  SJCp
# 278     d02  SJCV

# %%
pol = pkl.load(open('data/data_all_photo.pkl', "rb"))
aq_data = pd.DataFrame()

for n in list(pol.keys()):
    df = pol[n]
    df['station'] = n
    df['type'] = stations[stations.name == n].type.values[0]
    aq_data = pd.concat([aq_data,df])
aq_data
# Out:
#                             o3   no  no2   co  ben  tol pm10 pm2.5 code  \
# 2018-09-01 00:00:00-03:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   91
# 2018-09-01 01:00:00-03:00  NaN  NaN  NaN  1.3  NaN  NaN   87   NaN   91
# 2018-09-01 02:00:00-03:00  NaN  128   99  1.4  NaN  NaN   81   NaN   91
# 2018-09-01 03:00:00-03:00  NaN  215  110  2.3  NaN  NaN   92   NaN   91
# 2018-09-01 04:00:00-03:00  NaN  160   96  1.9  NaN  NaN   96   NaN   91
# ...                        ...  ...  ...  ...  ...  ...  ...   ...  ...
# 2018-10-31 20:00:00-03:00  NaN  NaN  NaN  NaN    0    1  NaN   NaN  278
# 2018-10-31 21:00:00-03:00  NaN  NaN  NaN  NaN    0    1  NaN   NaN  278
# 2018-10-31 22:00:00-03:00  NaN  NaN  NaN  NaN    1    2  NaN   NaN  278
# 2018-10-31 23:00:00-03:00  NaN  NaN  NaN  NaN    1    2  NaN   NaN  278
# 2018-11-01 00:00:00-03:00  NaN  NaN  NaN  NaN    0    6  NaN   NaN  278
#
#                                              station            type
# 2018-09-01 00:00:00-03:00            Cerqueira César           Urban
# 2018-09-01 01:00:00-03:00            Cerqueira César           Urban
# 2018-09-01 02:00:00-03:00            Cerqueira César           Urban
# 2018-09-01 03:00:00-03:00            Cerqueira César           Urban
# 2018-09-01 04:00:00-03:00            Cerqueira César           Urban
# ...                                              ...             ...
# 2018-10-31 20:00:00-03:00  S.José Campos-Vista Verde  Regional urban
# 2018-10-31 21:00:00-03:00  S.José Campos-Vista Verde  Regional urban
# 2018-10-31 22:00:00-03:00  S.José Campos-Vista Verde  Regional urban
# 2018-10-31 23:00:00-03:00  S.José Campos-Vista Verde  Regional urban
# 2018-11-01 00:00:00-03:00  S.José Campos-Vista Verde  Regional urban
#
# [8790 rows x 11 columns]

# %%
aq_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8790 entries, 2018-09-01 00:00:00-03:00 to 2018-11-01 00:00:00-03:00
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   o3       5173 non-null   object
#  1   no       5379 non-null   object
#  2   no2      5379 non-null   object
#  3   co       2210 non-null   object
#  4   ben      6906 non-null   object
#  5   tol      6906 non-null   object
#  6   pm10     6720 non-null   object
#  7   pm2.5    1454 non-null   object
#  8   code     8790 non-null   object
#  9   station  8790 non-null   object
#  10  type     8790 non-null   object
# dtypes: object(11)
# memory usage: 824.1+ KB

# %%
parameters = ['o3', 'no', 'no2', 'co', 'ben', 'tol', 'pm10', 'pm2.5']
for p in parameters:
    aq_data[p] = aq_data[p].astype(float)
aq_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8790 entries, 2018-09-01 00:00:00-03:00 to 2018-11-01 00:00:00-03:00
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   o3       5173 non-null   float64
#  1   no       5379 non-null   float64
#  2   no2      5379 non-null   float64
#  3   co       2210 non-null   float64
#  4   ben      6906 non-null   float64
#  5   tol      6906 non-null   float64
#  6   pm10     6720 non-null   float64
#  7   pm2.5    1454 non-null   float64
#  8   code     8790 non-null   object
#  9   station  8790 non-null   object
#  10  type     8790 non-null   object
# dtypes: float64(8), object(3)
# memory usage: 824.1+ KB

# %% [markdown]
# # Data Analysis

# %%
fig, ax = plt.subplots(5, sharex=True, sharey=True,figsize=(8,12))
for i,n in enumerate(aq_data.station.unique()[1:]):
    aq_data[aq_data.station == n][['ben','tol']].plot(secondary_y='ben', alpha=.8,ax=ax[i], legend=False)
    ax[i].set_title(n + " ("+stations[stations.name == n].type.values[0]+")", loc='left')
    if i == 0:
        ax[i].legend(['Benzene'], loc=1)
        plt.legend(['Toluene'], loc=2)
    if i == 2:
        ax[i].set_ylabel("Toluene [$\mu$gm$^{-3}$]")
        plt.ylabel('Benzene [$\mu$gm$^{-3}$]')
fig.savefig('fig/HC_CETESB_sep_oct2018.pdf',bbox_inches='tight',facecolor='w')

# %%
fig, ax = plt.subplots(sharex=True, figsize=(6,4))
t = 'Urban'
alpha = .1
df = aq_data[aq_data.type == t][['o3', 'no', 'no2', 'co','tol','ben']]
mean = df.groupby(df.index.hour).mean()
sd = df.groupby(df.index.hour).std()
    
mean.plot(y=['o3', 'no', 'no2'], 
          style=['-o','-','-s'], 
          color=['b', 'darkorange','r'], 
          lw=3,ax=ax, legend=False)
ax.fill_between(mean.index, mean.o3+sd.o3,mean.o3-sd.o3,
                       color='b',alpha=alpha )
#ax.fill_between(mean.index, mean.no+sd.no,mean.no-sd.no,
#                       color='darkorange',alpha=alpha)
#ax.fill_between(mean.index, mean.no2+sd.no2,mean.no2-sd.no2,
#                       color='r',alpha=alpha)
ax.set_ylim(0,120)
ax.set_title(t, loc='left', fontsize=8)
ax.set_xlabel('Hours (Local Time)')
plt.xticks(np.arange(0,24,2))
    
    
ax2 = ax.twinx()
mean.plot(y=['co','tol','ben'], ax=ax2, style=['-^g','-.c','-.k'], lw=2.5, legend=False)
ax2.set_ylim(0,8)
#ax2.fill_between(mean.index, mean.co+sd.co,mean.co-sd.co,
#                       color='g',alpha=alpha )
#ax2.fill_between(mean.index, mean.tol+sd.tol,mean.tol-sd.tol,
#                       color='c',alpha=alpha)
#ax2.fill_between(mean.index, mean.ben+sd.ben,mean.ben-sd.ben,
#                       color='k',alpha=alpha )

ax.set_ylabel('O$_3$, NO, NO$_2$ [$\mu$gm$^{-3}$]', loc='center')
ax2.set_ylabel('CO [ppm], Tol. and Ben. [$\mu$gm$^{-3}$]',loc='center')
ax.legend(['O$_3$','NO','NO$_2$'], ncol=3, fontsize=8, loc=2)
ax2.legend(['CO','Tol','Ben'], fontsize=8, loc=1, ncol=3)
fig.savefig('../4_Draft_Report/Dissertation/fig/byhour_all_polls.pdf', bbox_inches='tight', facecolor='w')
